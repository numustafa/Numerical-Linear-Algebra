# %% [markdown]
# # Ch 0 - Preliminaries

# %% [markdown]
# ## Trace of a Matrix
#
# only possible for *square matrix* & its just a scalar value:
#
# ![image.png](attachment:image.png)
#
# ### **Uses of Trace in Numerics of Linear Algeba:**
# #### 1. If A & B are similar marrices (means A = $P^{-1}BP$)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# #### 2. Sum of Eigenvalues & Connection to Frobenious Norms
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## Imp Concepts
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)
#
# **symmetric Matrices** have Real eigenvalues, even if the matrix is itself Complex.
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-10.png](attachment:image-10.png)
#
# ![image-11.png](attachment:image-11.png)
#
# ![image-12.png](attachment:image-12.png)
