# %% [markdown]
# # Ch 0 - Preliminaries

# %% [markdown]
# ## Trace of a Matrix
#
# only possible for *square matrix* & its just a scalar value:
#
# ![image.png](attachment:image.png)
#
# ### **Uses of Trace in Numerics of Linear Algeba:**
# #### 1. If A & B are similar marrices (means A = $P^{-1}BP$)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# #### 2. Sum of Eigenvalues & Connection to Frobenious Norms
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## Matrices & Imp Concepts
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)
#
# **Hermetian (symmetric in Complex space) Matrices** have Real eigenvalues, even if the matrix is itself Complex.
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-10.png](attachment:image-10.png)
#
# ![image-11.png](attachment:image-11.png)
#
# ![image-12.png](attachment:image-12.png)
# <br>
# <br>
#
# If **$A^{H}A=I_{n}$**, then A is a ***unitary***. This means $A^{H}=A^{-1}$. According to Lemma 0.1 (about A being non-singular), if A is non-singular, then $A^{H}A=AA^{H}=I_{n}$
#
# ![image-13.png](attachment:image-13.png)
#
# ![image-14.png](attachment:image-14.png)
#
# ![image-15.png](attachment:image-15.png)

# %% [markdown]
# ## Norms
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-7.png](attachment:image-7.png)
#
#
# ### Norm (Matrix norm) induced by Vector Norm
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# To Prove induced nor is a norm, just need to show induced norm satisfies the basic 3 conditions of Norm.
#
#
# #### P-norm (types of norms) induced by Vector Norm
#
# ![image-8.png](attachment:image-8.png)
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-10.png](attachment:image-10.png)

# %% [markdown]
# ### Vector norm induced by Norm
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
